# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyB6nTiWLefOMjHTKHhw1UcMGQEEP4ioW6c'
channel_ids = ['UCMhRreYsToOGT2dTcaQ7UZQ', # Truimph30 live
              'UCWHECOBvlhosLKVTHvw-3qw', # Fisayo Fosudo
              'UCTFFhYhkLkxjhcCdwUKmQ5g', # Korty eo
              'UC8p_y3iHPe-n3zRfXK2czWA', # Tayo Aina Films
              'UCzJIliq68IHSn-Kwgjeg2AQ', # Jackie Aina
              'UCx33BVeXro_mSJU-mNrqawg', # Samuel SinghNG
              'UCYqyzNqFk0VFSu4ngwopPpg', # BattaBox
              'UCaOV1eBHFLl18kH1bR0FmTA', # Valor Review
              'UCiuw1W3mkBrtl6kF8_KJMYw', # Maraji's World
              'UCsbMamQr8ORWLCL0fn07dfA', # Vivian Okezie
              'UC39zVnTMX-qJEfIRJSwuNhg', # Tomike Adeoye
              'UC9sU9W7_RM9LK2GpyEqYAhg', # Ihuoma Eze
              'UCeHgwTcKWbZhCNmdS96kTPA', # Oscarmini
              'UC1-P81CJbTJx6YeHNvNbCJw', # Kelechi Mgbemena
              'UCgiZJgpmzcbCW30ywLHVPkQ', # SisiYemmieTv
              'UCS1bu7fchbbZ9-FvjnIQhDg', # Layefa Ebitonmo
              'UCqyOnhmQ4eQ8km9apDzh7cg', # Tomi's Colour Pavilion
              'UCbqVxtjS0NVRcfBH27_GtEA', # Editorial beauty556
              'UCCNvbv5IQV77Gsh-c-v8nfg', # Zeelicious food
              'UCUocOQtoaHPuT0K8lME559A', # SamSpedy
              'UCaUfud8pU8ztkI45gxzPjzQ', # Dimma Umeh
              'UCB1KCA2K9ZJRy0Cds8plXKQ', # Eric Okafor
              'UCrHugJRAc7Zv_m73lgXxKfw', # Aproko Doctor,
              'UCyU8UEcfYE0_SBvp2EewAeA', # TokeMoments,
              'UC9unpsMUkOGDIMraqBfZtYg', # Dunsin Oyekan,
              'UCx2qMIoQIchX9o5x38hf1Bw', # NdaniTv,
              'UCQmZ9BIYOBSkxL-eqqg5z-g', # Mark Angel TV,
              'UC0LnPAjiEk6pZqd7bIzq4sw', # Emmanuel Iren Live,
              'UCQeBmVzhgTjYU7Wtlz5L1QQ', # Muyiiwa MG,
              'UC7lia91pef_7wznFnI6ZuzQ', # Akah Bants,
              'UC6AIZZlzcP3csZcPgltF22Q', # Josh2funny Ent,
              'UCkKHhORmLc14fmYvOa4Y7Ug', # Kraks TV
              'UCeMoPD4wqlfUQVZ7kiaAf9w', # Pulse NG
              'UCmaJwjJJkzMttK8L79g_8zA', # Red TV
              'UCbsX_BGv36fmskufsZaxndQ', # Ebonylife TV
              'UCKmaB1lFedMPSDF1i3mi3kw', # I said what I said Podcasts
              'UCxAkiUiL3KnMl0BIFBv6xxA', # Mr Macaroni
              'UCwnl91KSIqtPzPBvVqtWYqA', # Edem Victor
              'UCG6orNVuXIICv9_ifH6msIA', # Official Broda Shaggi
              'UC-iaCAZbuFSAmiSEQKgrC7Q', # Sydney Talker
              'UCIwUNuYEcZiiJqjU04yN30A', # Woliagba
               'UCDe1cg0CZOtzmrTCVCaTKpw', # Isbae U
              'UCxK9l27wsQ9RlA6lGRAcXAQ', # Amarachi Jacinth
              'UC6W70IG4xYBz8HXHdJoQPeA', # Komotion Studio
              'UCLIZiw4DQ7molZuxz9HcmbQ', # The Oludapos
              'UCQnOnATvW0uoSBpSDj1BPOA', # Jedidiah Adesoji
              'UCqTn2PSu7uxI-csLSTDx9Jg', # Anita Nwalo
              'UChmfF-juSBxYYic1rMsB_aA', # TNC Africa
              'UCM2wWHVLpEnXpHGfZTxxxjg', # The Nengers
              'UCVYa_MSgARc9cL75RPjUu_w', # The OTlovetrain
             
               
               
              ]

youtube = build('youtube', 'v3', developerKey= api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels(). list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute()
    
    for i in range(len (response['items'])):
        data = dict(Channel_name=response['items'][i]['snippet']['title'], 
                Subscribers= response['items'][i]['statistics']['subscriberCount'],
                Views= response['items'][i]['statistics']['viewCount'],
                Total_videos= response['items'][i]['statistics']['videoCount'] )
        all_data.append(data)
    return all_data

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_data= pd.DataFrame(channel_stats)

# %% [markdown]
# channel_data

# %%
channel_data['Subscribers']= pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']= pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']= pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data
# Out:
#                   Channel_name  Subscribers       Views  Total_videos
# 0                   Ihuoma Eze        29500     1958583           150
# 1                Valor Reviews       122000    22921347           257
# 2                  Jackie Aina      3540000   397389968           984
# 3             Zeelicious Foods       807000    45678300           514
# 4      AyoAjewole Woliagba-YPM       550000   120079357          1128
# 5                    Muyiwa MG        46500     1343242            54
# 6   EbonyLife Creative Academy         2370       81851            74
# 7             Amarachi Jacinth          529        6340            18
# 8             Jedidiah Adesoji          417        4338             9
# 9                  Eric Okafor       333000   127546291           365
# 10                SisiYemmieTV       862000    90349183          1102
# 11               Tomike Adeoye       109000    10986516            96
# ...

# %%
channel_data.to_csv('/data.csv')

# %%
channel_data
# Out:
#                   Channel_name  Subscribers       Views  Total_videos
# 0                   Ihuoma Eze        29500     1958583           150
# 1                Valor Reviews       122000    22921347           257
# 2                  Jackie Aina      3540000   397389968           984
# 3             Zeelicious Foods       807000    45678300           514
# 4      AyoAjewole Woliagba-YPM       550000   120079357          1128
# 5                    Muyiwa MG        46500     1343242            54
# 6   EbonyLife Creative Academy         2370       81851            74
# 7             Amarachi Jacinth          529        6340            18
# 8             Jedidiah Adesoji          417        4338             9
# 9                  Eric Okafor       333000   127546291           365
# 10                SisiYemmieTV       862000    90349183          1102
# 11               Tomike Adeoye       109000    10986516            96
# ...
