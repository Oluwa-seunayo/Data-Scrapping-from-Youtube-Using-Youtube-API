# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyB6nTiWLefOMjHTKHhw1UcMGQEEP4ioW6c'
channel_ids = ['UCQF2vue2E-KS5cwgNQ_dGOg', # Femi Okunuga,
              'UCZu6U2qCp66HIYdmzkvodNQ', # Z fancy,
              'UCr6qqKL4eQXxYfjMMhu5BWg', # Hype Squad,
              'UCZKveEdM9fe6mFR6Epth2TA', # Oga Sabinus,
              'UC5mUssTM2k7y2SQQpzGnjKA', # Ajele Comedian,
              'UCYWR5D0oC5lDGp_Yfh_EpFQ', # Titoluwa Sam-Oladapo,
              'UCw1CI9X0fOsQxf984GH2HYA', # Officer Woos,
              'UCfNoF7MELBNt1Lviq3F8cZQ', # Basketmouth,
              'UC47eU0u4OCMVr8PrVYjrRtg', # Mc Lively,
              'UCrJFGJoKyr4OfwO0CYDQAjw', # iam remotetv,
              'UCV8c3JPm_66QyEbJsecgW6A', # Lenstrokes,
              'UCuugO5O_RaGMQQ7EU32RuNQ', # Dyna Ekwueme,
              'UCIBYBeU6-i5ZaKRIOd7j1_Q', # Real House Of Comedy,
              'UCmT4al2RfF_ZNgHCiyRJMUg', # All Nigerian Foods,
              'UCk476VEayL_-XKbVWBX8VhQ', # Complete Sports,
              'UC2_bhZN_l3aTbW9djB_W67A', # Lade Ibikunle,
              'UCwo3STuRxkwVwxcKBO6jWAg', # Gist with Emy,
              'UC9T6ECutY4EPwJnGlbw4BzA', # TechPoint Africa,
              'UCH4wcxxvdl2f_UpKLu1MO8A', # Khalid Ozavogu Abdul,
              'UCGyPHwlkRV_Ai7aLRXpXJow', # Damilola Mike- Bamiloye,
              'UC0OJ2SXUy9FYkAClEijWcdQ', # Folasade Daini,
              'UCFV4M8KChgupV-ljIc6PFQA', # JayMikee,
              'UC1gZ-ZDcrMLXnJSTiuSLt0w', # The Geng,
              'UCimdZ5_SRe7Nym1kqpBwmpw', # Russet TV,
              'UCU5vdb5WCV3Klh4VE2EcILQ', # Madeaux Africa,
              'UCDl9SKeBkfAiqtytqc3N53g', # UGWUMBA TV,
              'UCWuhUxbEduCYF1kyuWp7sWw', # Taik2urhommie TV,
              'UCK8l22GkT_FXxhuyVqYcJow', # ,Grace Ajilore
              'UClga-D_n8Ut3fvfkCzBMRZg', # Tea With Tay Podcast,
              'UCdNaz9S2hcdZ6pkcsVYU1Lw', # Frances Theodore,
              'UCeSLrwEZPSQmt6KwQTzwyzw', # Accelerate TV,
              'UCt8doPAYaptSV_cBcUMFN3Q', # ToksTV,
              'UC95nwHulLAFtcUV7_ZanxPA', # MosesLDN,
              'UCj_IY06T93dst_kvD7UmKcw', # Emma OMG,
              'UCRhpD1WJFpPN2-w7J_Ppoug', # Ihechi Opara,
              'UCObjPIlZhzs7FuMidVB5ycg', # Eni Adeoluwa,
              'UCneM4DHHUWMVwmYktz8X46g', # Bimbo Ademoye TV,
              'UCvfxFuMblwizOBZbePuCzjQ', # LILIAN AFEGBAI TV,
              'UCMba4Tm8Cxj2uHhB4XH6wpQ', # Oluwadolarz Room Of Comedy,
              'UCtWuuTI-TVEFNgg-G_IIzKA', # SLKomedy,
              'UChzsfp0HIv9R3zEhcvofVkQ', # Echoo Room,
               'UCjoGGfRwpKLSNhFpgd5AM-w', # BOUNCE,
              'UCm6NRZvIcYwpj79CIa1Lj9g', # IBAKA TV,
              'UCOsuP5A7XW9Uq4x6QNUbf-g', # Awaw Tv,
              'UCuN9WLBBcjPp-xe7yfL4Ofw', # The Stalwart Lovers,
              'UClMWEMx-I2ABuVqvPf1pyAg', # Nasboi,
              'UCg4OvENOnZA2fIUJR9rMjPg', # Free me tv,
              'UCjNxItTi_FLfw97WoIBWgGA', # John Oguntuase,
              'UCdeoDVnKfjpIWXRU3Dug-Nw', # Hawa Magaji,
              'UC3C0OxzGKuFKJUpv-Dn-6fA', # With Chude
             
               
               
              ]

youtube = build('youtube', 'v3', developerKey= api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels(). list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute()
    
    for i in range(len (response['items'])):
        data = dict(Channel_name=response['items'][i]['snippet']['title'], 
                Subscribers= response['items'][i]['statistics']['subscriberCount'],
                Views= response['items'][i]['statistics']['viewCount'],
                Total_videos= response['items'][i]['statistics']['videoCount'] )
        all_data.append(data)
    return all_data

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_data= pd.DataFrame(channel_stats)

# %% [markdown]
# channel_data

# %%
channel_data['Subscribers']= pd.to_numeric(channel_data['Subscribers'])
channel_data['Views']= pd.to_numeric(channel_data['Views'])
channel_data['Total_videos']= pd.to_numeric(channel_data['Total_videos'])

# %%
channel_data
# Out:
#                      Channel_name  Subscribers      Views  Total_videos
# 0                    OFFICER WOOS       570000   78109827           256
# 1   Princess meeymee’s10 kitchen            26       6697            15
# 2                         Awaw TV        31800    3904409           428
# 3                 Complete Sports         5310     968024           738
# 4                        Bigwillz        14700    1771229           520
# 5                      Echoo Room        44800    3905180           172
# 6             The Stalwart Lovers       102000    6666016           222
# 7            Joshua Mike-Bamiloye       112000    5875286           168
# 8                Talk2UrHommie TV        64400    8799018           931
# 9                          Zfancy       390000   40000556           128
# 10           TitOluwa Sam-Oladapo        11400     790543           100
# 11                  Lade Ibikunle         3730     258229           191
# ...

# %%
channel_data.to_csv('/data2.csv')

# %%
channel_data
# Out:
#                      Channel_name  Subscribers      Views  Total_videos
# 0                    OFFICER WOOS       570000   78109827           256
# 1   Princess meeymee’s10 kitchen            26       6697            15
# 2                         Awaw TV        31800    3904409           428
# 3                 Complete Sports         5310     968024           738
# 4                        Bigwillz        14700    1771229           520
# 5                      Echoo Room        44800    3905180           172
# 6             The Stalwart Lovers       102000    6666016           222
# 7            Joshua Mike-Bamiloye       112000    5875286           168
# 8                Talk2UrHommie TV        64400    8799018           931
# 9                          Zfancy       390000   40000556           128
# 10           TitOluwa Sam-Oladapo        11400     790543           100
# 11                  Lade Ibikunle         3730     258229           191
# ...
